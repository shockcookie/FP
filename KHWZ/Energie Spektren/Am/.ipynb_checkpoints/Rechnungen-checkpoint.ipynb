# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Daten einlesen
def read (path):
    doc = []
    with open (path, 'r') as myfile:
        data = myfile.read().replace(',', '.').replace('\n', ',').replace('  ', ',').replace("\t",",")
        datarray = data.split(',')
        output = []
    for item in datarray:
        if item != '':
            output.append(int(item))
    return array(output)

# %%
data = read("Am_2_2.TKA")

#plt.figure(figsize=(11.7, 8.3), dpi=300)
plt.rc('grid', linestyle="-", color='black')
plt.plot(data)
plt.grid()
plt.show()

# %%
print(list(data).index(max(data)))
# Out:
# 374

# %%
en_cha=374/59.5
en_cha*14.4
# Out:
# 90.51428571428572

# %%
fig = plt.figure(figsize=(11.7, 8.3), dpi=300)
ax = fig.gca()
ax.set_xticks(numpy.arange(0, 1024, 50))
plt.plot(data)
plt.grid()
plt.show()

# %%
59.5-33.2
# Out:
# 26.299999999999997
